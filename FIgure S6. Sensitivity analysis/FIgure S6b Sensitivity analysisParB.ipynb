# %%
# Clear all existing variables
# %reset -f

# %%
#packages
import numpy as np
import matplotlib.pyplot as plt

# %%
# Widening the screen
from matplotlib import rcParams
# %matplotlib inline
# %config InlineBackend.figure_format = 'svg'
# Widening the screen
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:90% !important; }</style>"))
FS=25
rcParams['figure.dpi'] = 1800
rcParams['savefig.dpi'] = 800
rcParams['font.size'] = FS
rcParams['font.family'] = 'StixGeneral'
rcParams["mathtext.fontset"] = 'stix'
# rcParams["mathtext.default"] = "rm" 
# rcParams['xtick.direction'] = 'in'
plt.rc('font', size=FS)          # controls default text sizes
plt.rc('axes', titlesize=FS)     # fontsize of the axes title
plt.rc('axes', labelsize=FS)     # fontsize of the x and y labels
plt.rc('xtick', labelsize=FS)    # fontsize of the tick labels
plt.rc('ytick', labelsize=FS)    # fontsize of the tick labels
plt.rc('legend', fontsize=FS)    # legend fontsize
plt.rc('figure', titlesize=FS)   # fontsize of the figure title
# Out:
# <style>.container { width:90% !important; }</style>

# %%
#grid
LX =435
LT =31#1990-2020
dx =1.0
dt =0.001

# %%
#parameter
#Ph: N1
D1  =162.0
A11 =1.0
A21 =0.917
A31 =0.962

#Su: N2
D2  =10.0
A12 =1.0
A22 =1.0
A32 =1.0

#Sp: N3
D3  =78.5
A13 =1.0
A23 =0.984
A33 =1.0

R1  =np.zeros(LX)+1.0
R2  =np.zeros(LX)+1.0
R3  =np.zeros(LX)+1.0
R1[30:180] =R1[30:180]-np.linspace(1,0,150)
R2[30:180] =R2[30:180]-np.linspace(1,0,150)
R3[30:60]  =R3[30:60] -np.linspace(1,0,30)
R1[0:30] =0.0
R2[0:30] =0.0
R3[0:30] =0.0

# %%
#import data
import pandas
# area
df = pandas.read_csv('./Data S1 Percent cover.csv',header=0)
df1990   = df[df.Year == 1990]
df1990ph = df1990[df1990.Vegetation == 'ph']#
df1990su = df1990[df1990.Vegetation == 'su']
df1990sp = df1990[df1990.Vegetation == 'sp']

# %%
# salinity
dfe = pandas.read_csv('./Data S2 Salinity.csv',header=0)

# %%
# Salinity Before 1990
from numpy import polyfit, poly1d
dfe1990   = dfe[dfe['Year']<1990]
x1990     = dfe1990.Distance 
y1990     = dfe1990.Salinity
# polyfit
coeff1990 = polyfit(x1990, y1990, 1)
print(coeff1990)
# predict
f1990     = poly1d(coeff1990)
xnew1990  = np.linspace(0.0, (435.0-1.0)*30.0/1000.0,LX)
ynew1990  = f1990(xnew1990)
# Out:
# [0.02630668 0.62144737]

# %%
#initial value
N0 = 1.0
N1 = np.flipud( df1990ph.Percent_cover ) #Phragmites australis
N2 = np.flipud( df1990su.Percent_cover ) #Suaeda salsa
N3 = np.flipud( df1990sp.Percent_cover ) #Spartina alterniflora 

Ma = np.zeros((LT,LX))
Mb = np.zeros((LT,LX))
Mc = np.zeros((LT,LX))
Me = np.zeros((LT,LX))

# %%
#diffuse
def d2_dx2(Z): 
    Zleft = np.roll(Z, 1, axis=0)
    Zright = np.roll(Z, -1, axis=0)
    return (Zleft + Zright - 2.0 * Z) / dx**2

# %%
def d_dx(Z): # First order derivative that assumes periodic boundary conditions
    Zleft = np.roll(Z, 1, axis=0)
    Zcenter = Z[:]
    return (Zcenter - Zleft) / dx

# %% [markdown]
# # simulation

# %%
npoint = 1000
npointE = 2
AA = np.linspace(0.2, 0.2,1)#a=0.2
BB = np.linspace(0.6,1.6,npoint)#b=1.0
c  = np.flipud(ynew1990)
FF = np.linspace(0.02, 0.02,1)
DD = np.linspace(0.1, 0.1,1)
EE = np.linspace(0.0,0.18,npointE)

PhMean = np.zeros((npointE,npoint))
SuMean = np.zeros((npointE,npoint))
SpMean = np.zeros((npointE,npoint))

# %%
SuiB = 0
for a in AA:
    for b in BB:
        SuiE = 0
        for f in FF:
            for d in DD:
                for e in EE:
                #main simulation
                    N1     = np.flipud( df1990ph.Percent_cover )
                    N2     = np.flipud( df1990su.Percent_cover )
                    N3     = np.flipud( df1990sp.Percent_cover )
                    
                    E      = np.flipud(ynew1990)
                    Ma     =np.zeros((LT,LX))
                    Mb     =np.zeros((LT,LX))
                    Mc     =np.zeros((LT,LX))
                    Me     =np.zeros((LT,LX))
                    for j in range(int(LT)):
                        Ma[j,:] = N1
                        Mb[j,:] = N2
                        Mc[j,:] = N3
                        Me[j,:] = E
                        for i in range(int(1/dt)):
                            a12 = (A12/(E+a))
                            N1, N2, N3,E = \
                            N1 + dt*( D1*d2_dx2(N1) + N1*(R1-A11*N1-A21*N2-A31*N3) ),\
                            N2 + dt*( D2*d2_dx2(N2) + N2*(R2-a12*N1-A22*N2-A32*N3) ),\
                            N3 + dt*( D3*d2_dx2(N3) + N3*(R3-A13*N1-A23*N2-A33*N3) + 6.2*d_dx(N3) ),\
                            E  + dt*( f*(c - E) + d*N3/(b+N3)*E - e*np.sum(N3)/LX*E )

                            #boundary conditions
                            N1[0]=N1[1]
                            N1[LX-1]=N1[LX-2]
                            N2[0]=N2[1]
                            N2[LX-1]=N2[LX-2]
                            N3[0]=N3[1]
                            N3[LX-1]=N3[LX-2]
                            E[0]=E[1]
                            E[LX-1]=E[LX-2]
                    PhMean[SuiE,SuiB] = np.mean(N1)
                    SuMean[SuiE,SuiB] = np.mean(N2)
                    SpMean[SuiE,SuiB] = np.mean(N3)
                    SuiE = SuiE+1
        SuiB = SuiB+1
#         print(SuiE,SuiB,SuMean)

# %% [markdown]
# # save to csv

# %%
# import pandas as pd
# np.save('ParsAnalysis_B_BB.npy',BB)
# np.save('ParsAnalysis_B_PhMean.npy',PhMean)
# np.save('ParsAnalysis_B_SuMean.npy',SuMean)
# np.save('ParsAnalysis_B_SpMean.npy',SpMean)

# %%
# BB=np.load('ParsAnalysis_B_BB.npy')
# PhMean=np.load('ParsAnalysis_B_PhMean.npy')
# SuMean=np.load('ParsAnalysis_B_SuMean.npy')
# SpMean=np.load('ParsAnalysis_B_SpMean.npy')

# %% [markdown]
# # Plot

# %%
nticker = 6
from matplotlib import ticker
fig1, ax = plt.subplots(1, 1, figsize=(6, 6))
line10, = ax.plot(BB, PhMean[0,:]*100, lw=3, color='#00CCFF', linestyle='--', label='P. a. (e=0.0)'); 
line20, = ax.plot(BB, PhMean[1,:]*100, lw=3, color='#00CCFF', label='P. a. (e=0.07)'); 
line11, = ax.plot(BB, SuMean[0,:]*100, lw=3, color='r', linestyle='--', label='S. s. (e=0.0)'); 
line21, = ax.plot(BB, SuMean[1,:]*100, lw=3, color='r', label='S. s. (e=0.07)'); 
line12, = ax.plot(BB, SpMean[0,:]*100, lw=3, color='#009966', linestyle='--', label='S. a. (e=0.0)'); 
line22, = ax.plot(BB, SpMean[1,:]*100, lw=3, color='#009966', label='S. a. (e=0.07)');

ax.set_xlim(0.6, 1.6)
ax.set_xticks(np.linspace(0.6,1.6,nticker))

ax.set_ylim(0.0, 70)
# Ylabels = np.linspace(0.0, 0.7,nticker).round(1)
ax.set_yticks(np.linspace(0.0, 70,nticker))

ax.set_xlabel("Subsaturation constant, $b$");
ax.set_ylabel('Species coverage (%)');

ax.spines['bottom'].set_linewidth(1.5);
ax.spines['left'].set_linewidth(1.5);
ax.spines['right'].set_linewidth(1.5);
ax.spines['top'].set_linewidth(1.5);

# ax.legend(fontsize=15,frameon=False)
ax.grid()
fig1.savefig('FIgure S5b Sensitivity analysisParB.pdf',bbox_inches='tight')

# %% [markdown]
# © 2021, Kang Zhang, ECNU. Follow Johan van de Koppel & Quan-Xing Liu.
